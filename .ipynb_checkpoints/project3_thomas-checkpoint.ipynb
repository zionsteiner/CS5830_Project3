# %%
import numpy as np
import tweepy
import pandas as pd
import json
import seaborn
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
import re
from wordcloud import WordCloud

# %%
# # This is where I put my keys. It's probably best to just read them from the website that I created through
# # the twitter app because writing them out is a pain. Use json to read that in similar to Dr. Edwards code.
# CONSUMER_KEY = ''
# CONSUMER_SECRET_KEY = ''


# auth = tweepy.AppAuthHandler(CONSUMER_KEY, CONSUMER_SECRET_KEY)
# api = tweepy.API(auth)

# # # this should help us access tweets
# # twitter = Twython(CONSUMER_KEY, CONSUMER_SECRET_KEY, oauth_version=2)
# # ACCESS_TOKEN = twitter.obtain_access_token()

# # print('I have obtained my access token\n', ACCESS_TOKEN)


# # # statuses = twitter.search(q='49ers', geocode = '39.0997, 94.5786, 25mi' tweet_mode='extended', count=5000)['statuses']
# # # for status in statuses:
# # #     if 'retweeted_status' in status:
# # #         print(status['retweeted_Status']['full_text'])
# # #         status['full_test'] = status['retweeted_Status']['full_text']
# # #     else:
# # #         print(status['full_text'])
# # #     print()
    
# # # texts = [status['full_test']for status in statuses]

# %%
superbowl_tweets = pd.read_csv(r'superbowl_tweets.csv')
superbowl_tweets.head(20)
just_tweets = superbowl_tweets[['tweet']]
just_tweets.head(20)
# Out:
#                                                 tweet
# 0   Hopefully we can make the Players/coaches/orga...
# 1   Countless players relentlessly worked to recov...
# 2   fans, I hope we can put our focus towards than...
# 3   So - San Jose! The team needs to change their ...
# 4   : Congrats to The on a hard fought win. Thank ...
# 5   : To our : thank you for an incredible season,...
# 6   : To our : thank you for an incredible season,...
# 7   : To our : thank you for an incredible season,...
# 8   Keep this bunch together! They're special and ...
# 9   I was long over the disappointment for my ers ...
# 10  SUPER BOO HOO - it was heartache from tg quart...
# 11  Awesome breakdown as always. The tape here can...
# 12  Jimmy Garoppolo was force out. Rashad Fenton S...
# 13  : Matt Ryan under Kyle Shanahan... Season : ya...
# 14  : To our : thank you for an incredible season,...
# 15  : Matt Ryan under Kyle Shanahan... Season : ya...
# ...

# %%
# Convert the titles to lowercase
just_tweets['tweet'] = just_tweets['tweet'].str.lower()
just_tweets.head(20)
# Out:
# D:\Spyder\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                 tweet
# 0   hopefully we can make the players/coaches/orga...
# 1   countless players relentlessly worked to recov...
# 2   fans, i hope we can put our focus towards than...
# 3   so - san jose! the team needs to change their ...
# 4   : congrats to the on a hard fought win. thank ...
# 5   : to our : thank you for an incredible season,...
# 6   : to our : thank you for an incredible season,...
# 7   : to our : thank you for an incredible season,...
# 8   keep this bunch together! they're special and ...
# 9   i was long over the disappointment for my ers ...
# ...

# %%
# define punctuation
punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''

# Ideally, this next line of code will remove punctuations from the data base
